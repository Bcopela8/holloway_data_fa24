# %% [markdown]
# I am going to write out what my plans are in the markdown cells, Since I am still looking for a great deal of content. At the top here will be the simple introduction that all assignments require, I will then give a brief overview of the project and why this data matters! For me, I am driven by understanding how education and voting trends correlate. I have a strong belief that through education we can all develop more progressive mindsets and help society move forward, and that is what I am looking into with this project.
#
# I plan to utilize a lot of imagery for this project, I believe it is really important to break up big walls of text. As a Marketing focused person, I hope to make the notebook look a bit more appealing! The goal is to look more like an article posted to a corporate website than an analytical report, since they tend to be a bit duller on the eyes than an article would be.
#
# I will also speak on the source of my data and why I formatted how I did. My data came from the US Census on Educational Attainment. My data defines education as those who have achieved a bachelors degree or higher in each state. That percentage (seen in the dataframe below) is then taken and imported into MapChart, a took for creating maps, and given a color assignment. From there the percentage correlates to the color's value. The middle of the data was at the 36 point. The min and max were 24 and 48. So, with twelve on either side, I decided to have my highest zones 4 off from the center. Originally, I had them pull from 6, but the result was a bit too vague. For colorization, higher education has a blue color whole lower has a red (this is not favoritism, just happened to match the electoral graph for comparison).
#
# The goal here is to educate. So, I will start with an overview of education and how it effects us by outside report, then relate it to politics, then get into my topic and where my data came from. The end will primarily show the maps either top and bottom or side by side for comparison. A following part of the article will break down the analysis and possible limitations in a second "things to note" section. Of course it will all wrap up with a summary and conclusion, similar to any report like article.

# %%
import json
import pandas as pd

# %%
ex = pd.read_csv('ACSST1Y2023.S1501-Data.csv')
exA = ex[['NAME', 'S1501_C02_015E']]
exA
# Out:
#                     NAME                                     S1501_C02_015E
# 0   Geographic Area Name  Estimate!!Percent!!AGE BY EDUCATIONAL ATTAINME...
# 1                Alabama                                               28.9
# 2                 Alaska                                               32.2
# 3                Arizona                                               33.5
# 4               Arkansas                                               26.2
# 5             California                                               37.5
# 6               Colorado                                               46.4
# 7            Connecticut                                               42.9
# 8               Delaware                                               36.5
# 9   District of Columbia                                               65.9
# 10               Florida                                               34.9
# ...

# %% [markdown]
# ![Edu_Map.png](attachment:e2a2ea91-df44-4b26-8d2a-535f4891af53.png)

# %% [markdown]
# ![Elec_Map.webp](attachment:02254303-5b99-4a8a-b798-a3a77e5df167.webp)

# %% [markdown]
# As you can see from the maps and dataframe above, I have everything pretty much done! I want to rename the column on teh dataframe and maybe change the values to appear as percantages for the final version, but that is about it! A lot of what I am waiting on is the imagery. Because I am a marketing major, I try to find a way to utilize that and grow those skills even in classes that may not directly pertain to them. So, I am creating custom image content to use in this notebook! I am excited to finish it, but of course, the creative process takes time and sadly they are not ready quite yet to include in here.
#
# Thats the plan! If you have any recommendations about how I am going about things I would love to hear them! Feedback is always helpful for improvement! I loo forward to showing off the final project when all the custom creative content is finished!
