# %% [markdown]
# The data for my project is from the US Census and it is specifically based on Educational Attainment per state. The data goes back yearly until 2010. I collected the data by just downloading the dataset in a csv format diretly from their website (https://data.census.gov/table/ACSST5Y2022.S1501?q=state%20population%20by%20education). The data goes through levels of educational attainment from high school to levels of college educational attainment such as types of degrees and etc. I am specifically planning to utilize the "Bachelors degree or higher" value per state since it is the common degree of educational attainment in the united states. I will be organizing that data into states using lightscale coloring by state, and compare it to the US Elections results. My goal is to be able to do an analysis going back to 2010, but if not, at least using the data for 2023 which is the most recent data available in the sheet. I will load an example of the data below:

# %%
import json
import pandas as pd

# %%
ex = pd.read_csv('ACSST1Y2023.S1501-Data.csv')
ex.head()
# Out:
#         GEO_ID                  NAME  \
# 0    Geography  Geographic Area Name
# 1  0400000US01               Alabama
# 2  0400000US02                Alaska
# 3  0400000US04               Arizona
# 4  0400000US05              Arkansas
#
#                                       S1501_C01_001E  \
# 0  Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT...
# 1                                             479855
# 2                                              65148
# 3                                             701011
# 4                                             288490
#
#                                       S1501_C01_001M  \
# 0  Margin of Error!!Total!!AGE BY EDUCATIONAL ATT...
# 1                                               5966
# 2                                               2900
# 3                                               2509
# 4                                               5117
#
#                                       S1501_C01_002E  \
# ...

# %%
ex2 = pd.read_csv('ACSST1Y2023.S1501-Column-Metadata.csv')
ex2.head()
# Out:
#       Column Name                                              Label
# 0          GEO_ID                                          Geography
# 1            NAME                               Geographic Area Name
# 2  S1501_C01_001E  Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT...
# 3  S1501_C01_001M  Margin of Error!!Total!!AGE BY EDUCATIONAL ATT...
# 4  S1501_C01_002E  Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT...

# %% [markdown]
# As you can see from the above dataset, this data is extremely raw. I will likely have to do a great deal of tidy work to pull the exact values I need. The final tidy version of this dataset will be Each state with a percent beside it, and thats all. This is just an example of the 2023 csv's provided. Once I understand how to tidy one dataframe I should be able to do it with them all, organize based on year, and combine them all together! I have yet to decide if I will display them all individually or wether I will do an average of the percentages since 2010. Once I know the best way to organize that data I will be able to jump right in!
